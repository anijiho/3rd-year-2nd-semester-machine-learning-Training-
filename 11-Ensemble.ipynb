# %% [markdown]
# # random forest 구현

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
wine = pd.read_csv('https://bit.ly//wine_csv_data')
data = wine[['alcohol','sugar','pH']].to_numpy()
target = wine['class'].to_numpy()
train_input,test_input,train_target,test_target = train_test_split(data,target,test_size=0.2,random_state = 42)

# %%
from sklearn.model_selection import  cross_validate
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_jobs=-1,random_state=42)
scores = cross_validate(rf,train_input,train_target,return_train_score=True,n_jobs=-1)
print(np.mean(scores['train_score']),np.mean(scores['test_score']))

# %%
rf.fit(train_input,train_target)
print(rf.feature_importances_)

# %% [markdown]
# #OOB 샘플

# %%
rf = RandomForestClassifier(oob_score=True,n_jobs=-1,random_state=42)
rf.fit(train_input,train_target)
print(rf.oob_score_)

# %% [markdown]
# # 엑스트라 트리즈
# - 훈련 데이터를 전부 사용함
# - 어떤 노드를 분할 할지는 지니계수가 하는데 최적화로 분할 하는 것은 분할 계수가 한다. 지니계수를 측정하여 정보 이득을 구함
# -엑스트라 트리즈는 랜덤으로 노드를 분할 한다. 지니계수를 구하는 과정을 생략하기에 굉장히 빠르다.

# %%
from sklearn .ensemble import ExtraTreesClassifier
et = ExtraTreesClassifier(n_jobs=-1,random_state=42)
scores = cross_validate(et,train_input,train_target,return_train_score=True,n_jobs=-1)
print(np.mean(scores['train_score']),np.mean(scores['test_score']))

# %%
et.fit(train_input,train_target)
print(et.feature_importances_)

# %% [markdown]
# # 그레디언트 트리 부스팅(이런게 있다더라 어려워서)
# - 가장 강력한 모델 중 하나
# - 부스팅이란 뭔가 더해서 성능을 강력하게 만드는 기법이다.
# - 결정트리를 앞에서는 하나하나 정확하게 만들었는데 그레디언트 트리 부스팅은 깊이가 얕은 결정트리를 사용한다.
# - 각 결정트리에서 잘 안되는 애들을 고쳐주며 나아가는 방식을 반복하여
# estimate를 이용하여 가장 빠르게 처리한다.
# -경사 하강법을 이용하여 학습함
# - 로지스틱 손실함수 정의
# 평균 제곱 오차 함수를 손실함수로 정의 하여 학습 시킴
# -과대적합이 일어나지 않는다.
# 일반적으로 괜찮은 성능을 보장한다.
# # GDM
#
# -용어의 이해 설명을 키워드로 정확히 써 내려가야 한다.
# -프로그래밍 부분
# -우리가 다룬 예제 수준에서
# -어떤 파라미터 설정 매개변수 기억
# -지도학습의 주요 모델들
# -지도 학습 비지도학습
# -인공지능 머신러닝 딥러닝 차이

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbm = GradientBoostingClassifier(random_state=42)
scores = cross_validate(gbm,train_input,train_target,return_train_score=True,n_jobs=-1)
print(np.mean(scores['train_score']),np.mean(scores['test_score']))

# %%
gdm = GradientBoostingClassifier(n_estimators=500,learning_rate=0.2,random_state=42)
scores = cross_validate(gbm,train_input,train_target,return_train_score=True,n_jobs=-1)
print(np.mean(scores['train_score']),np.mean(scores['test_score']))

# %%
gbm.fit(train_input,train_target)
print(gbm.feature_importances_)
